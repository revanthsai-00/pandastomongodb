# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/neurolabDB")

# %%
dataBase = client["Inueron"]

# %%
collection = dataBase['AdmissionDetail']

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 12.2 MB 21.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 17.1 MB 71.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 498 kB 69.8 MB/s eta 0:00:01
# ...
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/config/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/vigneshk/Admission-Dataset/master/Admission.csv")
print(data)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
data=pd.DataFrame(data)
print(data)
# Out:
#      level_0  index  Serial No.  GRE Score  TOEFL Score  University Rating  \
# 0          0      0           1        337          118                  4
# 1          1      1           2        324          107                  4
# 2          2      2           3        316          104                  3
# 3          3      3           4        322          110                  3
# 4          4      4           5        314          103                  2
# ..       ...    ...         ...        ...          ...                ...
# 395      395    395         396        324          110                  3
# 396      396    396         397        325          107                  3
# 397      397    397         398        330          116                  4
# 398      398    398         399        312          103                  3
# 399      399    399         400        333          117                  4
#
#      SOP  LOR   CGPA  Research  Chance of Admit
# ...

# %%
data
# Out:
#      level_0  index  Serial No.  GRE Score  TOEFL Score  University Rating  \
# 0          0      0           1        337          118                  4
# 1          1      1           2        324          107                  4
# 2          2      2           3        316          104                  3
# 3          3      3           4        322          110                  3
# 4          4      4           5        314          103                  2
# ..       ...    ...         ...        ...          ...                ...
# 395      395    395         396        324          110                  3
# 396      396    396         397        325          107                  3
# 397      397    397         398        330          116                  4
# 398      398    398         399        312          103                  3
# 399      399    399         400        333          117                  4
#
#      SOP  LOR   CGPA  Research  Chance of Admit
# ...

# %%
#records=data.reset_index(inplace=True)
data_dict=(data.to_dict("records"))

# %%
print(list(data_dict))
# Out:
# ['level_0', 'index', 'Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research', 'Chance of Admit ']

# %%
collection.insert_many(data_dict)

# %%
result=collection.find()

# %%
for i in result:
    print(i)
# Out:
# {'_id': ObjectId('6392939dc7619cb31a47cf38'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('63929413eb84f0267dab6cd8'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('63929a5fc7619cb31a47cf3a'), 'level_0': 0, 'index': 0, 'Serial No.': 1, 'GRE Score': 337, 'TOEFL Score': 118, 'University Rating': 4, 'SOP': 4.5, 'LOR ': 4.5, 'CGPA': 9.65, 'Research': 1, 'Chance of Admit ': 0.92}
# {'_id': ObjectId('63929a5fc7619cb31a47cf3b'), 'level_0': 1, 'index': 1, 'Serial No.': 2, 'GRE Score': 324, 'TOEFL Score': 107, 'University Rating': 4, 'SOP': 4.0, 'LOR ': 4.5, 'CGPA': 8.87, 'Research': 1, 'Chance of Admit ': 0.76}
# ...
